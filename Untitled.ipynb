# %%
import pandas as pd

# %% [markdown]
# Project dedicated to check if education level has influence on the healthy life expectancy. Based on the data from Eurostat database.
# First step: examine correlation between education level, BMI and fruit&vegetables intake.
# Second step: examine additional factors: tobbaco, alcohol and PKB per capita.

# %%
bmi= pd.read_csv('bmi/hlth_ehis_bm1e_1_Data.csv')

# %%
bmi
# Out:
#               BMI                                        GEO        UNIT  \
# 0     Underweight  European Union - 27 countries (from 2020)  Percentage
# 1     Underweight  European Union - 27 countries (from 2020)  Percentage
# 2     Underweight  European Union - 27 countries (from 2020)  Percentage
# 3     Underweight  European Union - 27 countries (from 2020)  Percentage
# 4     Underweight  European Union - 27 countries (from 2020)  Percentage
# ...           ...                                        ...         ...
# 1219   Overweight                                     Turkey  Percentage
# 1220   Overweight                                     Turkey  Percentage
# 1221   Overweight                                     Turkey  Percentage
# 1222   Overweight                                     Turkey  Percentage
# 1223   Overweight                                     Turkey  Percentage
#
#       TIME                                            ISCED11      SEX    AGE  \
# 0     2014  Less than primary, primary and lower secondary...    Males  Total
# 1     2014  Less than primary, primary and lower secondary...  Females  Total
# 2     2014  Upper secondary and post-secondary non-tertiar...    Males  Total
# 3     2014  Upper secondary and post-secondary non-tertiar...  Females  Total
# 4     2014                    Tertiary education (levels 5-8)    Males  Total
# ...    ...                                                ...      ...    ...
# 1219  2019  Less than primary, primary and lower secondary...  Females  Total
# 1220  2019  Upper secondary and post-secondary non-tertiar...    Males  Total
# 1221  2019  Upper secondary and post-secondary non-tertiar...  Females  Total
# 1222  2019                    Tertiary education (levels 5-8)    Males  Total
# 1223  2019                    Tertiary education (levels 5-8)  Females  Total
#
#      Value  Flag and Footnotes
# 0      2.9                 NaN
# 1      4.5                 NaN
# 2      1.0                 NaN
# 3      3.8                 NaN
# 4      0.6                 NaN
# ...    ...                 ...
# 1219  67.9                 NaN
# 1220  52.0                 NaN
# 1221  39.7                 NaN
# 1222  59.4                 NaN
# 1223  32.7                 NaN
#
# [1224 rows x 9 columns]

# %%
bmi.columns
# Out:
# Index(['BMI', 'GEO', 'UNIT', 'TIME', 'ISCED11', 'SEX', 'AGE', 'Value',
#        'Flag and Footnotes'],
#       dtype='object')

# %%
bmi['BMI'].unique()
# Out:
# array(['Underweight', 'Normal', 'Overweight'], dtype=object)

# %%
fv_consumption = pd.read_csv('fruit_vegetables/hlth_ehis_fv3e_1_Data.csv')

# %%
fv_consumption
# Out:
#                N_PORTION                                        GEO  \
# 0             0 portions  European Union - 27 countries (from 2020)
# 1             0 portions  European Union - 27 countries (from 2020)
# 2             0 portions  European Union - 27 countries (from 2020)
# 3             0 portions  European Union - 27 countries (from 2020)
# 4             0 portions  European Union - 27 countries (from 2020)
# ...                  ...                                        ...
# 1219  5 portions or more                                     Turkey
# 1220  5 portions or more                                     Turkey
# 1221  5 portions or more                                     Turkey
# 1222  5 portions or more                                     Turkey
# 1223  5 portions or more                                     Turkey
#
#             UNIT  TIME                                            ISCED11  \
# 0     Percentage  2014  Less than primary, primary and lower secondary...
# 1     Percentage  2014  Less than primary, primary and lower secondary...
# 2     Percentage  2014  Upper secondary and post-secondary non-tertiar...
# 3     Percentage  2014  Upper secondary and post-secondary non-tertiar...
# 4     Percentage  2014                    Tertiary education (levels 5-8)
# ...          ...   ...                                                ...
# 1219  Percentage  2019  Less than primary, primary and lower secondary...
# 1220  Percentage  2019  Upper secondary and post-secondary non-tertiar...
# 1221  Percentage  2019  Upper secondary and post-secondary non-tertiar...
# 1222  Percentage  2019                    Tertiary education (levels 5-8)
# 1223  Percentage  2019                    Tertiary education (levels 5-8)
#
#           SEX    AGE Value  Flag and Footnotes
# 0       Males  Total  39.1                 NaN
# 1     Females  Total  30.5                 NaN
# 2       Males  Total  45.9                 NaN
# 3     Females  Total  33.8                 NaN
# 4       Males  Total  38.8                 NaN
# ...       ...    ...   ...                 ...
# 1219  Females  Total   3.3                 NaN
# 1220    Males  Total   2.5                 NaN
# 1221  Females  Total   2.6                 NaN
# 1222    Males  Total   2.1                 NaN
# 1223  Females  Total   3.4                 NaN
#
# [1224 rows x 9 columns]

# %%
life_expectancy = pd.read_csv('hlth_silc_17/hlth_silc_17_1_Data.csv')

# %%
life_expectancy.sample(25)
# Out:
#      TIME                                               GEO  \
# 94   2019                                            Cyprus
# 186  2019                                            Norway
# 85   2019                                             Italy
# 20   2019                                           Belgium
# 57   2019                                           Ireland
# 50   2019                                           Estonia
# 125  2019                                             Malta
# 73   2019                                            France
# 43   2019  Germany (until 1990 former territory of the FRG)
# 79   2019                                           Croatia
# 75   2019                                            France
# 116  2019                                           Hungary
# 102  2019                                         Lithuania
# 196  2019                                       Switzerland
# 179  2019                                            Sweden
# 187  2019                                            Norway
# 44   2019  Germany (until 1990 former territory of the FRG)
# 30   2019                                           Czechia
# 117  2019                                           Hungary
# 150  2019                                           Romania
# 200  2019                                    United Kingdom
# 158  2019                                          Slovenia
# 82   2019                                           Croatia
# 114  2019                                           Hungary
# 1    2019         European Union - 27 countries (from 2020)
#
#                                            INDIC_HE      SEX  UNIT Value  \
# 94       Health expectancy in absolute values at 65    Males  Year  15.4
# 186  Health expectancy in absolute values at birth     Males  Year  76.2
# 85   Health expectancy in absolute values at birth   Females  Year  80.0
# 20       Health expectancy in absolute values at 50    Males  Year  27.3
# 57       Health expectancy in absolute values at 50  Females  Year  33.5
# 50       Health expectancy in absolute values at 50    Males  Year  20.8
# 125      Health expectancy in absolute values at 65  Females  Year  19.4
# 73   Health expectancy in absolute values at birth   Females  Year  78.6
# 43   Health expectancy in absolute values at birth   Females  Year  77.2
# 79   Health expectancy in absolute values at birth   Females  Year  70.0
# 75       Health expectancy in absolute values at 50  Females  Year  31.5
# 116      Health expectancy in absolute values at 50    Males  Year  19.9
# 102  Health expectancy in absolute values at birth     Males  Year  65.4
# 196      Health expectancy in absolute values at 65    Males  Year  19.0
# 179      Health expectancy in absolute values at 65  Females  Year  20.1
# 187  Health expectancy in absolute values at birth   Females  Year  77.2
# 44       Health expectancy in absolute values at 50    Males  Year  26.5
# 30   Health expectancy in absolute values at birth     Males  Year  71.1
# 117      Health expectancy in absolute values at 50  Females  Year  23.8
# 150  Health expectancy in absolute values at birth     Males  Year  68.8
# 200      Health expectancy in absolute values at 50    Males  Year     :
# 158      Health expectancy in absolute values at 50    Males  Year  24.9
# 82       Health expectancy in absolute values at 65    Males  Year   9.9
# 114  Health expectancy in absolute values at birth     Males  Year  67.1
# 1    Health expectancy in absolute values at birth   Females  Year  77.0
#
#     Flag and Footnotes
# 94                 NaN
# 186                NaN
# 85                 NaN
# 20                   b
# 57                 NaN
# 50                 NaN
# 125                NaN
# 73                 NaN
# 43                 NaN
# 79                 NaN
# 75                 NaN
# 116                NaN
# 102                NaN
# 196                NaN
# 179                NaN
# 187                NaN
# 44                 NaN
# 30                 NaN
# 117                NaN
# 150                NaN
# 200                NaN
# 158                NaN
# 82                 NaN
# 114                NaN
# 1                  NaN
