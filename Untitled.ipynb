# %%
import pandas as pd

# %%
bmi= pd.read_csv('bmi/hlth_ehis_bm1e_1_Data.csv')

# %%
bmi
# Out:
#              BMI                                        GEO        UNIT  TIME  \
# 0    Underweight  European Union - 27 countries (from 2020)  Percentage  2014
# 1    Underweight  European Union - 27 countries (from 2020)  Percentage  2019
# 2    Underweight  European Union - 28 countries (2013-2020)  Percentage  2014
# 3    Underweight  European Union - 28 countries (2013-2020)  Percentage  2019
# 4    Underweight                                    Belgium  Percentage  2014
# ..           ...                                        ...         ...   ...
# 335        Obese                             United Kingdom  Percentage  2019
# 336        Obese                                     Serbia  Percentage  2014
# 337        Obese                                     Serbia  Percentage  2019
# 338        Obese                                     Turkey  Percentage  2014
# 339        Obese                                     Turkey  Percentage  2019
#
# ...

# %%
fv_consumption = pd.read_csv('fruit&vegetables/hlth_ehis_fv3e_1_Data.csv')

# %%
fv_consumption
# Out:
#               N_PORTION                                        GEO  \
# 0            0 portions  European Union - 27 countries (from 2020)
# 1            0 portions  European Union - 27 countries (from 2020)
# 2            0 portions  European Union - 28 countries (2013-2020)
# 3            0 portions  European Union - 28 countries (2013-2020)
# 4            0 portions                                    Belgium
# ..                  ...                                        ...
# 199  5 portions or more                             United Kingdom
# 200  5 portions or more                                     Serbia
# 201  5 portions or more                                     Serbia
# 202  5 portions or more                                     Turkey
# 203  5 portions or more                                     Turkey
#
#            UNIT  TIME                 ISCED11    SEX    AGE Value  \
# 0    Percentage  2014  All ISCED 2011 levels   Total  Total  36.0
# ...

# %%
education = pd.read_csv('edat_lfse_03/edat_lfse_03_1_Data.csv')

# %%
education
# Out:
#       TIME             GEO    SEX                  AGE        UNIT  \
# 0     2007         Austria  Total  From 15 to 64 years  Percentage
# 1     2007         Austria  Total  From 15 to 64 years  Percentage
# 2     2007         Austria  Total  From 15 to 64 years  Percentage
# 3     2007         Austria  Total  From 15 to 64 years  Percentage
# 4     2007         Belgium  Total  From 15 to 64 years  Percentage
# ...    ...             ...    ...                  ...         ...
# 2291  2020          Turkey  Total  From 15 to 64 years  Percentage
# 2292  2020  United Kingdom  Total  From 15 to 64 years  Percentage
# 2293  2020  United Kingdom  Total  From 15 to 64 years  Percentage
# 2294  2020  United Kingdom  Total  From 15 to 64 years  Percentage
# 2295  2020  United Kingdom  Total  From 15 to 64 years  Percentage
#
#                                                 ISCED11 Value  \
# 0     Less than primary, primary and lower secondary...  25.4
# ...

# %%
life_expectancy = pd.read_excel('tps00205_page_spreadsheet.xlsx')
# Out:
# /home/agnieszka/.local/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
life_expectancy
# Out:
#                                     Unnamed: 0  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4   Life expectancy at birth by sex [TPS00205]
# 5                            Open product page
# 6                                Description:
# 7                                          NaN
# 8                        Last update of data:
# 9              Last change of data structure:
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
#
# ...
