# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Project dedicated to check the relationship between education level, BMI, fruit&vegetables intake, and the healthy life expectancy.
# Data source: Eurostat database.

# %%
bmi= pd.read_csv('bmi/hlth_ehis_bm1e_1_Data.csv')

# %%
bmi['GEO'].unique()
# Out:
# array(['European Union - 27 countries (from 2020)',
#        'European Union - 28 countries (2013-2020)', 'Belgium', 'Bulgaria',
#        'Czechia', 'Denmark',
#        'Germany (until 1990 former territory of the FRG)', 'Estonia',
#        'Ireland', 'Greece', 'Spain', 'France', 'Croatia', 'Italy',
#        'Cyprus', 'Latvia', 'Lithuania', 'Luxembourg', 'Hungary', 'Malta',
#        'Netherlands', 'Austria', 'Poland', 'Portugal', 'Romania',
#        'Slovenia', 'Slovakia', 'Finland', 'Sweden', 'Iceland', 'Norway',
#        'United Kingdom', 'Serbia', 'Turkey'], dtype=object)

# %%
bmi.columns
# Out:
# Index(['BMI', 'GEO', 'UNIT', 'TIME', 'ISCED11', 'SEX', 'AGE', 'Value',
#        'Flag and Footnotes'],
#       dtype='object')

# %%
bmi['BMI'].unique()
# Out:
# array(['Underweight', 'Normal', 'Overweight'], dtype=object)

# %%
bmi['GEO'].unique()
# Out:
# array(['European Union - 27 countries (from 2020)',
#        'European Union - 28 countries (2013-2020)', 'Belgium', 'Bulgaria',
#        'Czechia', 'Denmark',
#        'Germany (until 1990 former territory of the FRG)', 'Estonia',
#        'Ireland', 'Greece', 'Spain', 'France', 'Croatia', 'Italy',
#        'Cyprus', 'Latvia', 'Lithuania', 'Luxembourg', 'Hungary', 'Malta',
#        'Netherlands', 'Austria', 'Poland', 'Portugal', 'Romania',
#        'Slovenia', 'Slovakia', 'Finland', 'Sweden', 'Iceland', 'Norway',
#        'United Kingdom', 'Serbia', 'Turkey'], dtype=object)

# %%
bmi.describe(include = ['O'])
# Out:
#                 BMI                                        GEO        UNIT  \
# count          1224                                       1224        1224
# unique            3                                         34           1
# top     Underweight  European Union - 27 countries (from 2020)  Percentage
# freq            408                                         36        1224
#
#                                                   ISCED11    SEX    AGE Value
# count                                                1224   1224   1224  1224
# unique                                                  3      2      1   421
# top     Less than primary, primary and lower secondary...  Males  Total     :
# freq                                                  408    612   1224    54

# %% [markdown]
# First conclusions: data frame contains 1224 records. There are 3 BMI values: Underweight, Normal and Overweigth. Data covers 34 countries (including collected information for the EU), 3 education levels, provides differentiation between man and women, but not the age. Therefore the column: AGE can also be removed.

# %% [markdown]
# bmi data cleaning:
# - remove columns: UNIT, AGE, Flag and Footnotes, as they contain information not relevant for the analysis
# - check for missing data and either remove or fill. No missing values except column: Flag and Footnotes.
# - as the analysis will be done per country, data for the whole EU can be removed
# - remove data from 2014

# %%
sns.heatmap(bmi.isnull())
# Out:
# <AxesSubplot:>

# %%
bmi.drop('UNIT', axis=1, inplace=True)

# %%
bmi.drop('Flag and Footnotes', axis = 1, inplace=True)

# %%
bmi.drop('AGE', axis = 1, inplace = True)

# %%
countries = bmi['GEO'].unique().tolist()[2:]

# %%
bmi_single_countries = bmi[bmi['GEO'].isin(countries)].copy()
bmi_single_countries
# Out:
#               BMI      GEO  TIME  \
# 24    Underweight  Belgium  2014
# 25    Underweight  Belgium  2014
# 26    Underweight  Belgium  2014
# 27    Underweight  Belgium  2014
# 28    Underweight  Belgium  2014
# ...           ...      ...   ...
# 1219   Overweight   Turkey  2019
# 1220   Overweight   Turkey  2019
# 1221   Overweight   Turkey  2019
# 1222   Overweight   Turkey  2019
# 1223   Overweight   Turkey  2019
#
#                                                 ISCED11      SEX Value
# 24    Less than primary, primary and lower secondary...    Males   4.8
# 25    Less than primary, primary and lower secondary...  Females   4.7
# 26    Upper secondary and post-secondary non-tertiar...    Males   1.3
# 27    Upper secondary and post-secondary non-tertiar...  Females   3.3
# 28                      Tertiary education (levels 5-8)    Males   0.7
# ...                                                 ...      ...   ...
# ...

# %%
bmi_2019 = bmi_single_countries[bmi_single_countries['TIME'] == 2019].copy()
bmi_2019
# Out:
#               BMI      GEO  TIME  \
# 30    Underweight  Belgium  2019
# 31    Underweight  Belgium  2019
# 32    Underweight  Belgium  2019
# 33    Underweight  Belgium  2019
# 34    Underweight  Belgium  2019
# ...           ...      ...   ...
# 1219   Overweight   Turkey  2019
# 1220   Overweight   Turkey  2019
# 1221   Overweight   Turkey  2019
# 1222   Overweight   Turkey  2019
# 1223   Overweight   Turkey  2019
#
#                                                 ISCED11      SEX Value
# 30    Less than primary, primary and lower secondary...    Males   3.2
# 31    Less than primary, primary and lower secondary...  Females   5.3
# 32    Upper secondary and post-secondary non-tertiar...    Males   1.4
# 33    Upper secondary and post-secondary non-tertiar...  Females   3.3
# 34                      Tertiary education (levels 5-8)    Males   0.9
# ...                                                 ...      ...   ...
# ...

# %%
def change_to_number(x):
    if x == ':':
        return 0
    else:
        return float(x)

bmi_2019['Value'] = bmi_2019['Value'].apply(lambda x: change_to_number(x))

# %%
education_descriptions = bmi_2019['ISCED11'].unique().tolist()
education_simplified = ['lower', 'middle', 'upper']
education_dict = {name:number for name,number in zip(education_descriptions, education_simplified)}
education_dict
# Out:
# {'Less than primary, primary and lower secondary education (levels 0-2)': 'lower',
#  'Upper secondary and post-secondary non-tertiary education (levels 3 and 4)': 'middle',
#  'Tertiary education (levels 5-8)': 'upper'}

# %%
bmi_2019['education_level'] = bmi_2019['ISCED11'].map(education_dict)

# %%
bmi_2019
# Out:
#               BMI      GEO  TIME  \
# 30    Underweight  Belgium  2019
# 31    Underweight  Belgium  2019
# 32    Underweight  Belgium  2019
# 33    Underweight  Belgium  2019
# 34    Underweight  Belgium  2019
# ...           ...      ...   ...
# 1219   Overweight   Turkey  2019
# 1220   Overweight   Turkey  2019
# 1221   Overweight   Turkey  2019
# 1222   Overweight   Turkey  2019
# 1223   Overweight   Turkey  2019
#
#                                                 ISCED11      SEX  Value  \
# 30    Less than primary, primary and lower secondary...    Males    3.2
# 31    Less than primary, primary and lower secondary...  Females    5.3
# 32    Upper secondary and post-secondary non-tertiar...    Males    1.4
# 33    Upper secondary and post-secondary non-tertiar...  Females    3.3
# 34                      Tertiary education (levels 5-8)    Males    0.9
# ...                                                 ...      ...    ...
# ...

# %%
pivot_bmi = bmi_2019.pivot_table(values = 'Value', index = 'education_level', columns = 'BMI').round(2)

# %%
pivot_bmi
# Out:
# BMI              Normal  Overweight  Underweight
# education_level
# lower             39.89       52.94         4.05
# middle            40.57       53.64         2.66
# upper             47.70       46.66         2.51

# %%
pivot_bmi.plot(kind = 'bar', stacked=True, title = 'BMI vs education level')
# Out:
# <AxesSubplot:title={'center':'BMI vs education level'}, xlabel='education_level'>

# %%
pivot_bmi_M_F = bmi_2019.pivot_table(values = 'Value', index = 'education_level', columns = ['BMI', 'SEX']).round(2)

# %%
pivot_bmi_M_F
# Out:
# BMI              Normal        Overweight        Underweight
# SEX             Females  Males    Females  Males     Females Males
# education_level
# lower             39.78  39.99      52.17  53.71        4.92  3.18
# middle            46.24  34.90      46.55  60.72        4.08  1.25
# upper             56.02  39.38      36.51  56.82        4.35  0.67

# %%
pivot_bmi_M_F['Overweight'].plot.bar()
# Out:
# <AxesSubplot:xlabel='education_level'>

# %% [markdown]
# Conclusion: Based on data from all EU countries, in the group with highest education the mean % of overweight citizens is > 6 %points lower than in the groups with education levels 0-2 and 3-4. In the group with lowest education level the % of underweight citizens is significantly higher than in the other groups. When the split into males and females is taken into consideration, it becomes apparent that the % of underweight males decreases with the increasing education level, while in the females group it is between 4-5% regardless of the education. In the group with lowest education the % of overweight females and males is almost equal (52.17 and 53.71%, respectively), while in the 2 other groups there is a vast difference depending on sex: there is 15 to 20% points less overweight females than males.

# %%
fv_consumption = pd.read_csv('fruit_vegetables/hlth_ehis_fv3e_1_Data.csv')

# %%
fv_consumption
# Out:
#                N_PORTION                                        GEO  \
# 0             0 portions  European Union - 27 countries (from 2020)
# 1             0 portions  European Union - 27 countries (from 2020)
# 2             0 portions  European Union - 27 countries (from 2020)
# 3             0 portions  European Union - 27 countries (from 2020)
# 4             0 portions  European Union - 27 countries (from 2020)
# ...                  ...                                        ...
# 1219  5 portions or more                                     Turkey
# 1220  5 portions or more                                     Turkey
# 1221  5 portions or more                                     Turkey
# 1222  5 portions or more                                     Turkey
# 1223  5 portions or more                                     Turkey
#
#             UNIT  TIME                                            ISCED11  \
# 0     Percentage  2014  Less than primary, primary and lower secondary...
# ...

# %%
fv_consumption['Value'] = fv_consumption['Value'].apply(lambda x: change_to_number(x))

# %%
fv_consumption.describe(include = ['O'])
# Out:
#          N_PORTION                                        GEO        UNIT  \
# count         1224                                       1224        1224
# unique           3                                         34           1
# top     0 portions  European Union - 27 countries (from 2020)  Percentage
# freq           408                                         36        1224
#
#                                                   ISCED11    SEX    AGE
# count                                                1224   1224   1224
# unique                                                  3      2      1
# top     Less than primary, primary and lower secondary...  Males  Total
# freq                                                  408    612   1224

# %%
fv_consumption['N_PORTION'].unique()
# Out:
# array(['0 portions', 'From 1 to 4 portions', '5 portions or more'],
#       dtype=object)

# %%
sns.heatmap(fv_consumption.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# fv_consumption data cleaning:
#
# - remove columns: UNIT, AGE,  Flag and Footnotes, as they contain information not relevant for the analysis
# - check for missing data and either remove or fill. No missing values except column: Flag and Footnotes.
# - as the analysis will be done per country, data for the whole EU can be removed
# - remove data from 2014
# - create column with education level as in bmi Data Frame.

# %%
fv_consumption.drop('UNIT', axis=1, inplace=True)

# %%
fv_consumption.drop('AGE', axis=1, inplace=True)

# %%
fv_consumption.drop('Flag and Footnotes', axis=1, inplace=True)

# %%
fv_consumption_single_countries = fv_consumption[fv_consumption['GEO'].isin(countries)].copy()
fv_consumption_single_countries
# Out:
#                N_PORTION      GEO  TIME  \
# 24            0 portions  Belgium  2014
# 25            0 portions  Belgium  2014
# 26            0 portions  Belgium  2014
# 27            0 portions  Belgium  2014
# 28            0 portions  Belgium  2014
# ...                  ...      ...   ...
# 1219  5 portions or more   Turkey  2019
# 1220  5 portions or more   Turkey  2019
# 1221  5 portions or more   Turkey  2019
# 1222  5 portions or more   Turkey  2019
# 1223  5 portions or more   Turkey  2019
#
#                                                 ISCED11      SEX  Value
# 24    Less than primary, primary and lower secondary...    Males   22.2
# 25    Less than primary, primary and lower secondary...  Females   14.1
# 26    Upper secondary and post-secondary non-tertiar...    Males   19.5
# 27    Upper secondary and post-secondary non-tertiar...  Females   14.3
# 28                      Tertiary education (levels 5-8)    Males   15.5
# ...

# %%
fv_consumption_2019 = fv_consumption_single_countries[fv_consumption_single_countries['TIME'] == 2019].copy()
fv_consumption_2019
# Out:
#                N_PORTION      GEO  TIME  \
# 30            0 portions  Belgium  2019
# 31            0 portions  Belgium  2019
# 32            0 portions  Belgium  2019
# 33            0 portions  Belgium  2019
# 34            0 portions  Belgium  2019
# ...                  ...      ...   ...
# 1219  5 portions or more   Turkey  2019
# 1220  5 portions or more   Turkey  2019
# 1221  5 portions or more   Turkey  2019
# 1222  5 portions or more   Turkey  2019
# 1223  5 portions or more   Turkey  2019
#
#                                                 ISCED11      SEX  Value
# 30    Less than primary, primary and lower secondary...    Males   24.7
# 31    Less than primary, primary and lower secondary...  Females   17.1
# 32    Upper secondary and post-secondary non-tertiar...    Males   22.9
# 33    Upper secondary and post-secondary non-tertiar...  Females   16.2
# 34                      Tertiary education (levels 5-8)    Males   16.7
# ...

# %%
fv_consumption_2019['education_level'] = fv_consumption_2019['ISCED11'].map(education_dict)
fv_consumption_2019
# Out:
#                N_PORTION      GEO  TIME  \
# 30            0 portions  Belgium  2019
# 31            0 portions  Belgium  2019
# 32            0 portions  Belgium  2019
# 33            0 portions  Belgium  2019
# 34            0 portions  Belgium  2019
# ...                  ...      ...   ...
# 1219  5 portions or more   Turkey  2019
# 1220  5 portions or more   Turkey  2019
# 1221  5 portions or more   Turkey  2019
# 1222  5 portions or more   Turkey  2019
# 1223  5 portions or more   Turkey  2019
#
#                                                 ISCED11      SEX  Value  \
# 30    Less than primary, primary and lower secondary...    Males   24.7
# 31    Less than primary, primary and lower secondary...  Females   17.1
# 32    Upper secondary and post-secondary non-tertiar...    Males   22.9
# 33    Upper secondary and post-secondary non-tertiar...  Females   16.2
# 34                      Tertiary education (levels 5-8)    Males   16.7
# ...

# %%
portions = fv_consumption_2019['N_PORTION'].unique().tolist()
portions_new = ['0', '1-4', '5 or more']
portions_dict = dict(zip(portions, portions_new))
fv_consumption_2019['portions'] = fv_consumption_2019['N_PORTION'].map(portions_dict)

# %%
fv_consumption_2019
# Out:
#                N_PORTION      GEO  TIME  \
# 30            0 portions  Belgium  2019
# 31            0 portions  Belgium  2019
# 32            0 portions  Belgium  2019
# 33            0 portions  Belgium  2019
# 34            0 portions  Belgium  2019
# ...                  ...      ...   ...
# 1219  5 portions or more   Turkey  2019
# 1220  5 portions or more   Turkey  2019
# 1221  5 portions or more   Turkey  2019
# 1222  5 portions or more   Turkey  2019
# 1223  5 portions or more   Turkey  2019
#
#                                                 ISCED11      SEX  Value  \
# 30    Less than primary, primary and lower secondary...    Males   24.7
# 31    Less than primary, primary and lower secondary...  Females   17.1
# 32    Upper secondary and post-secondary non-tertiar...    Males   22.9
# 33    Upper secondary and post-secondary non-tertiar...  Females   16.2
# 34                      Tertiary education (levels 5-8)    Males   16.7
# ...

# %%
pivot_fv_cons = fv_consumption_2019.pivot_table(values = 'Value', index = 'education_level', columns = 'portions').round(2)
pivot_fv_cons
# Out:
# portions             0    1-4  5 or more
# education_level
# lower            40.35  47.78       8.74
# middle           37.32  49.30      10.26
# upper            29.54  53.10      14.24

# %%
pivot_fv_cons.plot.bar(stacked = True, title = 'Consumption of fruit and vegetables vs education level')
# Out:
# <AxesSubplot:title={'center':'Consumption of fruit and vegetables vs education level'}, xlabel='education_level'>

# %%
pivot_fv_cons_M_F = fv_consumption_2019.pivot_table(values = 'Value', index = 'education_level', columns = ['portions', 'SEX']).round(2)
pivot_fv_cons_M_F
# Out:
# portions              0            1-4        5 or more
# SEX             Females  Males Females  Males   Females  Males
# education_level
# lower             35.54  45.16   51.36  44.21      9.97   7.51
# middle            31.59  43.05   53.15  45.44     12.13   8.39
# upper             23.86  35.23   55.71  50.48     17.32  11.15

# %%
pivot_fv_cons_M_F['5 or more'].plot.bar()
# Out:
# <AxesSubplot:xlabel='education_level'>

# %% [markdown]
# Conclusions: consumption of fruit and vegetables is clearly higher in the group with higher education level. Among EU citizens with lower education only 8.74% consume 5 or more portions per day. Even in the best educated group almost 30% of citizens don't consume fruit and vegetables at all. In all groups females tend to eat more fruit and vegetables than men. Further promotion of fruit and vegetables intake needs to take place, as these are the best sources of vitamins, minerals, dietary fiber and many other nutrients. Intake of 5 portions of diverse fruit and vegetables every day is known to have positive effect on health, prevent cancer and cardiovalcular disease.

# %%
life_exp = pd.read_csv('hlth_silc_17/hlth_silc_17_1_Data.csv')

# %%
life_expectancy = life_exp[life_exp['GEO'].isin(countries)].copy()

# %%
choices = life_expectancy['INDIC_HE'].unique().tolist()
choices
# Out:
# ['Health expectancy in absolute values at birth ',
#  'Health expectancy in absolute values at 50',
#  'Health expectancy in absolute values at 65']

# %%
life_exp_at_birth = life_expectancy[(life_expectancy['INDIC_HE'] == choices[0]) & (life_expectancy['Value'] != ':')].copy()

# %%
life_exp_by_sex = life_exp_at_birth.pivot_table(values = 'Value', index = 'GEO', columns = 'SEX').sort_values(by = 'Females', ascending = False)

# %%
life_exp_by_sex.plot.line(title = 'Life expectancy at birth for females and males in the EU countries', rot = 90, figsize=(15,5))
# Out:
# <AxesSubplot:title={'center':'Life expectancy at birth for females and males in the EU countries'}, xlabel='GEO'>

# %%
bmi_by_sex_and_ed = bmi_2019[bmi_2019['BMI'] == 'Overweight'].sort_values(by = 'Value', ascending = False)

# %%
bmi_by_sex_and_ed.pivot = bmi_by_sex_and_ed.pivot_table(values = 'Value', index = 'GEO', columns = 'SEX').sort_values(by = 'Females')

# %%
bmi_by_sex_and_ed.pivot.plot.line(title = '% of overweight males and females in EU countries', rot = 90, figsize = (15,5))
# Out:
# <AxesSubplot:title={'center':'% of overweight males and females in EU countries'}, xlabel='GEO'>

# %% [markdown]
# Conclusions: It is remarkable that expected lifespan is higher for females than males in all EU countries. It could be investigated further if the observed higher intake of fruit and vegetables and lower obesity rate among women is one of the factors influencing the life expectancy.

# %%
life_exp_at_birth
life_exp_index = life_exp_at_birth['GEO'].tolist()
# Out:
# 56

# %%
life_exp_at_birth.index = life_exp_index
life_exp_at_birth
# Out:
#                                                   TIME  \
# Belgium                                           2019
# Belgium                                           2019
# Bulgaria                                          2019
# Bulgaria                                          2019
# Czechia                                           2019
# Czechia                                           2019
# Denmark                                           2019
# Denmark                                           2019
# Germany (until 1990 former territory of the FRG)  2019
# Germany (until 1990 former territory of the FRG)  2019
# Estonia                                           2019
# Estonia                                           2019
# Ireland                                           2019
# Ireland                                           2019
# Greece                                            2019
# Greece                                            2019
# ...

# %%
def change_description(x):
    if x == "Males":
        return 'Males-le'
    elif x == 'Females':
        return 'Females-le'
    else:
        pass
   
life_exp_at_birth['SEX'] = life_exp_at_birth['SEX'].apply(lambda x: change_description(x))

# %%
life_exp_at_birth
# Out:
#                                                   TIME  \
# Belgium                                           2019
# Belgium                                           2019
# Bulgaria                                          2019
# Bulgaria                                          2019
# Czechia                                           2019
# Czechia                                           2019
# Denmark                                           2019
# Denmark                                           2019
# Germany (until 1990 former territory of the FRG)  2019
# Germany (until 1990 former territory of the FRG)  2019
# Estonia                                           2019
# Estonia                                           2019
# Ireland                                           2019
# Ireland                                           2019
# Greece                                            2019
# Greece                                            2019
# ...

# %%
life_exp_at_birth_average = life_exp_at_birth.pivot_table(values = 'Value', index = 'GEO', columns = 'SEX').round(2)
life_exp_at_birth_average
# Out:
# SEX                                               Females-le  Males-le
# GEO
# Austria                                                 77.5      74.2
# Belgium                                                 77.1      74.2
# Bulgaria                                                72.9      67.5
# Croatia                                                 70.0      66.5
# Cyprus                                                  78.4      75.8
# Czechia                                                 75.1      71.1
# Denmark                                                 76.9      74.9
# Estonia                                                 73.3      67.3
# Finland                                                 80.7      75.6
# France                                                  78.6      74.0
# Germany (until 1990 former territory of the FRG)        77.2      73.7
# Greece                                                  78.8      75.2
# ...

# %%
bmi_2019 = bmi_2019[bmi_2019['BMI'] == 'Overweight'].copy()
bmi_2019_average = bmi_2019.pivot_table(values = 'Value', index = 'GEO', columns = 'SEX').round(2)

# %%
bmi_2019_average.index
# Out:
# Index(['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany (until 1990 former territory of the FRG)', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malta', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania',
#        'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Turkey',
#        'United Kingdom'],
#       dtype='object', name='GEO')

# %%
life_exp_at_birth_average.index
# Out:
# Index(['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany (until 1990 former territory of the FRG)', 'Greece', 'Hungary',
#        'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Slovakia',
#        'Slovenia', 'Spain', 'Sweden'],
#       dtype='object', name='GEO')

# %%
comparison_bmi_le = pd.concat([bmi_2019_average, life_exp_at_birth_average], axis=1)
comparison_bmi_le
# Out:
# SEX                                               Females  Males  Females-le  \
# GEO
# Austria                                             43.43  58.27        77.5
# Belgium                                             44.43  54.23        77.1
# Bulgaria                                            44.53  61.07        72.9
# Croatia                                             57.07  70.07        70.0
# Cyprus                                              41.33  57.73        78.4
# Czechia                                             46.67  60.10        75.1
# Denmark                                             43.20  54.30        76.9
# Estonia                                             50.97  56.80        73.3
# Finland                                             54.80  60.70        80.7
# France                                              38.07  48.67        78.6
# Germany (until 1990 former territory of the FRG)    43.50  57.57        77.2
# ...

# %%
refined_table = comparison_bmi_le.dropna()
refined_table
# Out:
# SEX                                               Females  Males  Females-le  \
# GEO
# Austria                                             43.43  58.27        77.5
# Belgium                                             44.43  54.23        77.1
# Bulgaria                                            44.53  61.07        72.9
# Croatia                                             57.07  70.07        70.0
# Cyprus                                              41.33  57.73        78.4
# Czechia                                             46.67  60.10        75.1
# Denmark                                             43.20  54.30        76.9
# Estonia                                             50.97  56.80        73.3
# Finland                                             54.80  60.70        80.7
# France                                              38.07  48.67        78.6
# Germany (until 1990 former territory of the FRG)    43.50  57.57        77.2
# ...

# %%
av_le_females = (refined_table['Females-le']).mean().round(2)
av_le_females
# Out:
# 76.05

# %%
median_le_females = (refined_table['Females-le']).median().round(2)
median_le_females
# Out:
# 77.0

# %%
av_le_males = (refined_table['Males-le']).mean().round(2)
av_le_males
# Out:
# 72.5

# %%
median_le_males = (refined_table['Males-le']).median().round(2)
median_le_males
# Out:
# 74.1

# %%
females_BMI_LE = refined_table['Females'].corr(refined_table['Females-le'])

# %%
females_BMI_LE.round(2)
# Out:
# -0.4

# %%
males_BMI_LE = refined_table['Males'].corr(refined_table['Males-le'])
males_BMI_LE.round(2)
# Out:
# -0.14

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.scatter(refined_table['Females'], refined_table['Females-le'])
plt.xlabel('% overweight citizens')
plt.ylabel('life expectancy at birth[years]')
plt.title('Life expectancy vs BMI for females in the EU countries')


plt.subplot(1,2,2)
plt.scatter(refined_table['Males'], refined_table['Males-le'])
plt.xlabel('% overweight citizens')
plt.ylabel('life expectancy at birth[years]')
plt.title('Life expectancy vs BMI for males in the EU countries')
# Out:
# Text(0.5, 1.0, 'Life expectancy vs BMI for males in the EU countries')

# %%
refined_table.describe()
# Out:
# SEX      Females      Males  Females-le   Males-le
# count  28.000000  28.000000   28.000000  28.000000
# mean   46.423929  58.616429   76.053571  72.503571
# std     5.457509   4.857277    3.682942   4.528305
# min    32.930000  48.670000   70.000000  64.200000
# 25%    43.252500  55.722500   72.750000  67.450000
# 50%    45.500000  58.000000   77.000000  74.100000
# 75%    50.640000  61.202500   78.900000  75.900000
# max    57.070000  70.070000   81.900000  78.700000

# %% [markdown]
# Conclusions: correlation coefficient between % of overweight citizens and life expectancy at birth was calculated for the EU countries. In both groups(males and females) correlation coefficient is negative, meaning that higher % of overweight citizens results in lower life expectancy. In females group value = -0.4, so the correlations is moderate, in males group it is close to 0 (-0.14). In EU countries % of overweight females varies from 32.9% to 57.07%, overweight males from 48.67% to 70.07%. Life expectancy at birth for females and males varies from 70 to 81.9 years and from 64.2 to 78.7 years, respectively.
